# %% [markdown]
# <a href="https://colab.research.google.com/github/ananddiv/datascience/blob/Linear-Regression/Multilinear_scaffold_R2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install helper
# Out:
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for helper: filename=helper-2.5.0-py2.py3-none-any.whl size=19168 sha256=046232d1e8001cd290dbb3f4c74d23edbaa95981c2657cb1e1b9b43be9043928
#   Stored in directory: /root/.cache/pip/wheels/13/8a/92/4a4267b8371d6e453121c917021173b4a682d691f123b9f647
# Successfully built helper
# ...

# %%
# Import necessary libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from helper1 import fit_and_plot_linear, fit_and_plot_multi
# %matplotlib inline

# %%
# Read the file "Advertising.csv"
df = pd.read_csv("Advertising.csv")

# Take a quick look at the dataframe
df.head()
# Out:
#       TV  Radio  Newspaper  Sales
# 0  230.1   37.8       69.2   22.1
# 1   44.5   39.3       45.1   10.4
# 2   17.2   45.9       69.3    9.3
# 3  151.5   41.3       58.5   18.5
# 4  180.8   10.8       58.4   12.9

# %%
df_new = df.drop(columns = 'Sales')

# %%
df_new
# Out:
#         TV  Radio  Newspaper
# 0    230.1   37.8       69.2
# 1     44.5   39.3       45.1
# 2     17.2   45.9       69.3
# 3    151.5   41.3       58.5
# 4    180.8   10.8       58.4
# ..     ...    ...        ...
# 195   38.2    3.7       13.8
# 196   94.2    4.9        8.1
# 197  177.0    9.3        6.4
# 198  283.6   42.0       66.2
# 199  232.1    8.6        8.7
#
# [200 rows x 3 columns]

# %%
data= {"A":[10,20,30],"B":["a","b","c"],"C":[1,2,3]}
df1 = pd.DataFrame(data)
sample_list= [40,"d",4]
df2 = pd.DataFrame([sample_list], columns=df.columns)
df1 = df.append(df2,ignore_index=True)
df1

# %%
# gives a tuple of column name and series
# for each column in the dataframe
for (columnName, columnData) in df_new.iteritems():
    print('Column Name : ', columnName)
    print('Column Contents : ', columnData.values)

# %%
# Define an empty Pandas dataframe to store the R-squared value associated with each
# predictor for both the train and test split
df_results = pd.DataFrame(columns=['Predictor', 'R2 Train', 'R2 Test'])

# %%
from os import XATTR_CREATE
# For each predictor in the dataframe, call the function "fit_and_plot_linear()"
# from the helper file with the predictor as a parameter to the function

# This function will split the data into train and test split, fit a linear model
# on the train data and compute the R-squared value on both the train and test data

# **Your code here**
x = df[["TV"]]
r2_train0, r2_test0 = fit_and_plot_linear(x)
#df_results.loc[1] = ["TV",r2_train,r2_test]

x = df[["Radio"]]
r2_train1, r2_test1 = fit_and_plot_linear(x)
#df_results.loc[2] = ["Radio",r2_train,r2_test]

x = df[["Newspaper"]]
r2_train2, r2_test2 = fit_and_plot_linear(x)
#df_results.loc[3] = ["Newspaper",r2_train,r2_test]

x = df[["Sales"]]
r2_train3, r2_test3 = fit_and_plot_linear(x)
#df_results.loc[4] = ["Sales",r2_train,r2_test]


#for ind,colnames in enumerate(df):
  #x = df[[colnames]]
  #r2_train, r2_test = fit_and_plot_linear(x)
  #df_results.loc[ind] = ["Sales",r2_train,r2_test]

# %% [markdown]
# ⏸ Based on the plot and results, which model do you think is the best for prediction?
#
# #### A. TV
# #### B. Radio
# #### C. Newspaper
# #### D. Sales

# %%
### edTest(test_chow1) ###
# Submit an answer choice as a string below
# (Eg. if you choose option C, put 'C')
answer1 = 'A'

# %%
# Call the function "fit_and_plot_multi()" from the helper to fit a multilinear model
# on the train data and compute the R-squared value on both the train and test data

# **Your code here**
r2_train, r2_test  = fit_and_plot_multi()
#df_results.loc[5] = ["Multilinear",r2_train, r2_test]

# %%
### edTest(test_dataframe) ###

# Store the R-squared values for all models
# in the dataframe intialized above
# **Your code here**
df_results.loc[0] = ["TV",r2_train0,r2_test0]
df_results.loc[1] = ["Radio",r2_train1,r2_test1]
df_results.loc[2] = ["Newspaper",r2_train2,r2_test2]
#df_results.loc[3] = ["Sales",r2_train3,r2_test3]
df_results.loc[4] = ["All",r2_train, r2_test]

# Take a quick look at the dataframe
df_results.head()
# Out:
#    Predictor  R2 Train   R2 Test
# 0         TV  0.588474  0.676315
# 1      Radio  0.356718  0.229817
# 2  Newspaper  0.064416 -0.021217
# 3      Sales  1.000000  1.000000
# 4        All  0.906711  0.860115

# %% [markdown]
# ⏸ Why do you think the mutilinear regression model is better?
#
# #### A. The model goes to the gym thrice as more when compare to the linear model.
# #### B. The model has more information from various predictors/features.
# #### C. The model is not linear, hence fits the complex data.
# #### D. The model is not better than the simple linear regression.

# %%
### edTest(test_chow2) ###
# Submit an answer choice as a string below
# (Eg. if you choose option C, put 'C')
answer2 = 'B'
