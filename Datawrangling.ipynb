# %% [markdown]
# <a href="https://colab.research.google.com/github/ananddiv/datascience/blob/main/Datawrangling.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("HousePrices.csv")

# %%
df.shape
# Out:
# (4600, 18)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4600 entries, 0 to 4599
# Data columns (total 18 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   date           4600 non-null   object
#  1   price          4600 non-null   float64
#  2   bedrooms       4600 non-null   float64
#  3   bathrooms      4600 non-null   float64
#  4   sqft_living    4600 non-null   int64
#  5   sqft_lot       4600 non-null   int64
#  6   floors         4600 non-null   float64
#  7   waterfront     4600 non-null   int64
#  8   view           4600 non-null   int64
#  9   condition      4600 non-null   int64
#  10  sqft_above     4600 non-null   int64
#  11  sqft_basement  4600 non-null   int64
#  12  yr_built       4600 non-null   int64
#  13  yr_renovated   4600 non-null   int64
#  14  street         4600 non-null   object
#  15  city           4600 non-null   object
#  16  statezip       4600 non-null   object
# ...

# %%
df.describe()
# Out:
#               price     bedrooms    bathrooms   sqft_living      sqft_lot  \
# count  4.600000e+03  4600.000000  4600.000000   4600.000000  4.600000e+03
# mean   5.519630e+05     3.400870     2.160815   2139.346957  1.485252e+04
# std    5.638347e+05     0.908848     0.783781    963.206916  3.588444e+04
# min    0.000000e+00     0.000000     0.000000    370.000000  6.380000e+02
# 25%    3.228750e+05     3.000000     1.750000   1460.000000  5.000750e+03
# 50%    4.609435e+05     3.000000     2.250000   1980.000000  7.683000e+03
# 75%    6.549625e+05     4.000000     2.500000   2620.000000  1.100125e+04
# max    2.659000e+07     9.000000     8.000000  13540.000000  1.074218e+06
#
#             floors   waterfront         view    condition   sqft_above  \
# count  4600.000000  4600.000000  4600.000000  4600.000000  4600.000000
# mean      1.512065     0.007174     0.240652     3.451739  1827.265435
# std       0.538288     0.084404     0.778405     0.677230   862.168977
# ...

# %%
df.head()
# Out:
#                   date      price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# 0  2014-05-02 00:00:00   313000.0       3.0       1.50         1340      7912
# 1  2014-05-02 00:00:00  2384000.0       5.0       2.50         3650      9050
# 2  2014-05-02 00:00:00   342000.0       3.0       2.00         1930     11947
# 3  2014-05-02 00:00:00   420000.0       3.0       2.25         2000      8030
# 4  2014-05-02 00:00:00   550000.0       4.0       2.50         1940     10500
#
#    floors  waterfront  view  condition  sqft_above  sqft_basement  yr_built  \
# 0     1.5           0     0          3        1340              0      1955
# 1     2.0           0     4          5        3370            280      1921
# 2     1.0           0     0          4        1930              0      1966
# 3     1.0           0     0          4        1000           1000      1963
# 4     1.0           0     0          4        1140            800      1976
#
# ...

# %%
df.dtypes
# Out:
# date              object
# price            float64
# bedrooms         float64
# bathrooms        float64
# sqft_living        int64
# sqft_lot           int64
# floors           float64
# waterfront         int64
# view               int64
# condition          int64
# sqft_above         int64
# sqft_basement      int64
# yr_built           int64
# yr_renovated       int64
# street            object
# city              object
# statezip          object
# country           object
# dtype: object

# %%
df.memory_usage()
# Out:
# Index              128
# date             36800
# price            36800
# bedrooms         36800
# bathrooms        36800
# sqft_living      36800
# sqft_lot         36800
# floors           36800
# waterfront       36800
# view             36800
# condition        36800
# sqft_above       36800
# sqft_basement    36800
# yr_built         36800
# yr_renovated     36800
# street           36800
# city             36800
# statezip         36800
# country          36800
# dtype: int64

# %%
df['yr_built'] = df['yr_built'].astype('int8')

# %%
df.dtypes
# Out:
# date              object
# price            float64
# bedrooms         float64
# bathrooms        float64
# sqft_living        int64
# sqft_lot           int64
# floors           float64
# waterfront         int64
# view               int64
# condition          int64
# sqft_above         int64
# sqft_basement      int64
# yr_built            int8
# yr_renovated       int64
# street            object
# city              object
# statezip          object
# country           object
# dtype: object

# %%
df.memory_usage()
# Out:
# Index              128
# date             36800
# price            36800
# bedrooms         36800
# bathrooms        36800
# sqft_living      36800
# sqft_lot         36800
# floors           36800
# waterfront       36800
# view             36800
# condition        36800
# sqft_above       36800
# sqft_basement    36800
# yr_built          4600
# yr_renovated     36800
# street           36800
# city             36800
# statezip         36800
# country          36800
# dtype: int64

# %%
df.groupby(['city','yr_built'])['price','bedrooms'].mean()
# Out:
# <ipython-input-31-df49ce087659>:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   df.groupby(['city','yr_built'])['price','bedrooms'].mean()
#                            price  bedrooms
# city         yr_built
# Algona       1956       100000.0       2.0
#              1960       230000.0       3.0
#              1992       196440.0       3.0
#              2002       262000.0       4.0
#              2006       248000.0       4.0
# ...                          ...       ...
# Woodinville  2013       646212.5       4.0
# Yarrow Point 1949       899000.0       3.0
#              1953        84350.0       4.0
#              1969      1895000.0       5.0
#              1992      1901000.0       3.0
#
# [1300 rows x 2 columns]

# %%
df.head()
# Out:
#                   date      price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# 0  2014-05-02 00:00:00   313000.0       3.0       1.50         1340      7912
# 1  2014-05-02 00:00:00  2384000.0       5.0       2.50         3650      9050
# 2  2014-05-02 00:00:00   342000.0       3.0       2.00         1930     11947
# 3  2014-05-02 00:00:00   420000.0       3.0       2.25         2000      8030
# 4  2014-05-02 00:00:00   550000.0       4.0       2.50         1940     10500
#
#    floors  waterfront  view  condition  sqft_above  sqft_basement  yr_built  \
# 0     1.5           0     0          3        1340              0       -93
# 1     2.0           0     4          5        3370            280      -127
# 2     1.0           0     0          4        1930              0       -82
# 3     1.0           0     0          4        1000           1000       -85
# 4     1.0           0     0          4        1140            800       -72
#
# ...

# %%
df.groupby('city')['price'].max()
# Out:
# city
# Algona                   262000.0
# Auburn                   900000.0
# Beaux Arts Village       745000.0
# Bellevue                7062500.0
# Black Diamond            650000.0
# Bothell                  749995.0
# Burien                  1035000.0
# Carnation               1680000.0
# Clyde Hill              3800000.0
# Covington               2199900.0
# Des Moines               950000.0
# Duvall                   955000.0
# Enumclaw                 687000.0
# Fall City               1600000.0
# Federal Way              819000.0
# Inglewood-Finn Hill      425000.0
# Issaquah                2238888.0
# Kenmore                 1120000.0
# Kent                   26590000.0
# Kirkland                3000000.0
# Lake Forest Park         790000.0
# Maple Valley             725000.0
# Medina                  3710000.0
# Mercer Island           4668000.0
# Milton                   320000.0
# Newcastle               1200000.0
# Normandy Park           1309500.0
# ...

# %%
df.groupby('city')['price'].min()
# Out:
# city
# Algona                 100000.000000
# Auburn                      0.000000
# Beaux Arts Village     745000.000000
# Bellevue                    0.000000
# Black Diamond               0.000000
# Bothell                347000.000000
# Burien                      0.000000
# Carnation               80000.000000
# Clyde Hill                  0.000000
# Covington                   0.000000
# Des Moines             140000.000000
# Duvall                 117833.333333
# Enumclaw                    0.000000
# Fall City              275000.000000
# Federal Way                 0.000000
# Inglewood-Finn Hill    425000.000000
# Issaquah                    0.000000
# Kenmore                     0.000000
# Kent                        0.000000
# Kirkland                90000.000000
# Lake Forest Park            0.000000
# Maple Valley                0.000000
# Medina                 188000.000000
# Mercer Island               0.000000
# Milton                 250000.000000
# ...

# %%
df.loc[0,['date','city']]
# Out:
# date    2014-05-02 00:00:00
# city              Shoreline
# Name: 0, dtype: object

# %%
df['month'] = pd.DatetimeIndex(df['date']).month

# %%
df['year'] = pd.DatetimeIndex(df['date']).year

# %%
df['day'] = pd.DatetimeIndex(df['date']).day

# %%
df.dtypes
# Out:
# date             datetime64[ns]
# price                   float64
# bedrooms                float64
# bathrooms               float64
# sqft_living               int64
# sqft_lot                  int64
# floors                  float64
# waterfront                int64
# view                      int64
# condition                 int64
# sqft_above                int64
# sqft_basement             int64
# yr_built                  int64
# yr_renovated              int64
# street                   object
# city                     object
# statezip                 object
# country                  object
# month                     int64
# year                      int64
# day                       int64
# dtype: object

# %%
x = df.loc[0,['date']]

# %%
df.head()
# Out:
#         date      price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  \
# 0 2014-05-02   313000.0       3.0       1.50         1340      7912     1.5
# 1 2014-05-02  2384000.0       5.0       2.50         3650      9050     2.0
# 2 2014-05-02   342000.0       3.0       2.00         1930     11947     1.0
# 3 2014-05-02   420000.0       3.0       2.25         2000      8030     1.0
# 4 2014-05-02   550000.0       4.0       2.50         1940     10500     1.0
#
#    waterfront  view  condition  ...  sqft_basement  yr_built  yr_renovated  \
# 0           0     0          3  ...              0      1955          2005
# 1           0     4          5  ...            280      1921             0
# 2           0     0          4  ...              0      1966             0
# 3           0     0          4  ...           1000      1963             0
# 4           0     0          4  ...            800      1976          1992
#
# ...

# %%
df.set_index([','city'],inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-84-0248b37d1b90> in <cell line: 1>()
# ----> 1 df.set_index(['date','city'],inplace=True)
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     329                     stacklevel=find_stack_level(),
#     330                 )
# --> 331             return func(*args, **kwargs)
#     332
#     333         # error: "Callable[[VarArg(Any), KwArg(Any)], Any]" has no
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in set_index(self, keys, drop, append, inplace, verify_integrity)
#    6010
#    6011         if missing:
# -> 6012             raise KeyError(f"None of {missing} are in the columns")
#    6013
#    6014         if inplace:
#
# KeyError: "None of ['date'] are in the columns"

# %%
df.reset_index(inplace = True)

# %%
df.head()
# Out:
#                       index      price  bedrooms  bathrooms  sqft_living  \
# date       city
# 2014-05-02 Shoreline      0   313000.0       3.0       1.50         1340
#            Seattle        1  2384000.0       5.0       2.50         3650
#            Kent           2   342000.0       3.0       2.00         1930
#            Bellevue       3   420000.0       3.0       2.25         2000
#            Redmond        4   550000.0       4.0       2.50         1940
#
#                       sqft_lot  floors  waterfront  view  condition  \
# date       city
# 2014-05-02 Shoreline      7912     1.5           0     0          3
#            Seattle        9050     2.0           0     4          5
#            Kent          11947     1.0           0     0          4
#            Bellevue       8030     1.0           0     0          4
#            Redmond       10500     1.0           0     0          4
#
#                       sqft_above  sqft_basement  yr_built  yr_renovated  \
# ...

# %%
df.set_index(['date','city'], inplace=True)

# %%
df.reset_index(inplace = True)

# %%
df.set_index(['city'], inplace = True)

# %%
df.loc['2014-05-02'].loc['Seattle']
# Out:
#          index      price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  \
# city
# Seattle      1  2384000.0       5.0       2.50         3650      9050     2.0
# Seattle      5   490000.0       2.0       1.00          880      6380     1.0
# Seattle      9   640000.0       4.0       2.00         1520      6200     1.5
# Seattle     11  1400000.0       4.0       2.50         2920      4000     1.5
# Seattle     13   365000.0       3.0       1.00         1090      6435     1.0
# Seattle     14  1200000.0       5.0       2.75         2910      9480     1.5
# Seattle     20   750000.0       3.0       1.75         2240     10578     2.0
# Seattle     22   626000.0       3.0       2.25         1750      1572     2.5
# Seattle     24   495000.0       4.0       1.75         1600      6380     1.0
# Seattle     26   615000.0       3.0       1.75         2360      7291     1.0
# Seattle     29   790000.0       3.0       2.50         2600      4750     1.0
# ...

# %%
df1 = pd.read_csv('Merge1.csv')
df2 = pd.read_csv('Merge2.csv')

# %%
df1.head()
# Out:
#          date      a   b    c
# 0  2022-01-01   9000  35  140
# 1  2022-01-02   8000  12  920
# 2  2022-01-03  69000  42  370
# 3  2022-01-04  81000  29  900
# 4  2022-01-05  91000  35  770

# %%
df2.head()
# Out:
#          date      a   b    c
# 0  2022-03-01  12000  50   60
# 1  2022-03-02  27000  90  990
# 2  2022-03-03  19000  17  750
# 3  2022-03-04  70000  60  900
# 4  2022-03-05   6000   7  810

# %%
pd.merge(df1,df2,how = 'inner', on='date')
# Out:
#           date    a_x  b_x  c_x    a_y  b_y  c_y
# 0   2022-03-01  16000   29  360  12000   50   60
# 1   2022-03-02  56000   73  990  27000   90  990
# 2   2022-03-03   3000   99  650  19000   17  750
# 3   2022-03-04  36000   94  310  70000   60  900
# 4   2022-03-05  59000   17  600   6000    7  810
# 5   2022-03-06  35000   57  450  10000   98  730
# 6   2022-03-07  86000   98  130  41000   21  710
# 7   2022-03-08  69000   44   60  80000   76  200
# 8   2022-03-09  21000   64  930  78000   46  200
# 9   2022-03-10  45000   83  670  74000   67   50
# 10  2022-03-11  65000   83  910  13000   20   70
# 11  2022-03-12  86000   50  280   9000    8  100
# 12  2022-03-13  35000   57  790  44000   56  350
# 13  2022-03-14  14000    2   50  44000   34  370
# 14  2022-03-15  87000   72  350  39000   29  420
# 15  2022-03-16  55000   58  990  21000   37  920
# 16  2022-03-17   3000   27  160  59000    1  480
# 17  2022-03-18  58000   70   50  19000   17  850
# ...

# %%
pd.merge(df1,df2,how = 'left', on = 'date')
# Out:
#           date    a_x  b_x  c_x      a_y   b_y    c_y
# 0   2022-01-01   9000   35  140      NaN   NaN    NaN
# 1   2022-01-02   8000   12  920      NaN   NaN    NaN
# 2   2022-01-03  69000   42  370      NaN   NaN    NaN
# 3   2022-01-04  81000   29  900      NaN   NaN    NaN
# 4   2022-01-05  91000   35  770      NaN   NaN    NaN
# ..         ...    ...  ...  ...      ...   ...    ...
# 85  2022-03-27  37000   90  260  17000.0  89.0  230.0
# 86  2022-03-28  24000   24  950  97000.0  69.0  790.0
# 87  2022-03-29  44000    7  400  47000.0  54.0  970.0
# 88  2022-03-30  31000   10  600  72000.0  27.0  600.0
# 89  2022-03-31  28000   65  740  80000.0  17.0  370.0
#
# [90 rows x 7 columns]

# %%
pd.merge(df1,df2,how = 'inner', on = 'date', suffixes = ('_1','_2'))
# Out:
#           date    a_1  b_1  c_1    a_2  b_2  c_2
# 0   2022-03-01  16000   29  360  12000   50   60
# 1   2022-03-02  56000   73  990  27000   90  990
# 2   2022-03-03   3000   99  650  19000   17  750
# 3   2022-03-04  36000   94  310  70000   60  900
# 4   2022-03-05  59000   17  600   6000    7  810
# 5   2022-03-06  35000   57  450  10000   98  730
# 6   2022-03-07  86000   98  130  41000   21  710
# 7   2022-03-08  69000   44   60  80000   76  200
# 8   2022-03-09  21000   64  930  78000   46  200
# 9   2022-03-10  45000   83  670  74000   67   50
# 10  2022-03-11  65000   83  910  13000   20   70
# 11  2022-03-12  86000   50  280   9000    8  100
# 12  2022-03-13  35000   57  790  44000   56  350
# 13  2022-03-14  14000    2   50  44000   34  370
# 14  2022-03-15  87000   72  350  39000   29  420
# 15  2022-03-16  55000   58  990  21000   37  920
# 16  2022-03-17   3000   27  160  59000    1  480
# 17  2022-03-18  58000   70   50  19000   17  850
# ...

# %%
l1 = [1,2,3,pd.NA,5]
l2 = [6,7,pd.NA,9,10]

# %%
df4 = pd.DataFrame(list(zip(l1,l2)),columns = ['col1','col2'])

# %%
df4['col1'] = df4['col1'].astype('str')
df4['col2'] = df4['col2'].astype('string')

# %%
df4.dtypes
# Out:
# col1    object
# col2    string
# dtype: object

# %%
df4
# Out:
#    col1  col2
# 0     1     6
# 1     2     7
# 2     3  <NA>
# 3  <NA>     9
# 4     5    10

# %%
type(df4.loc[3,'col1'])
# Out:
# str

# %%
type(df4.loc[2,'col2'])
# Out:
# pandas._libs.missing.NAType

# %%
data = {'a':[1,2,np.nan],'b':[1,np.nan,3],'c':[1,np.nan,np.nan]}

# %%
df5 = pd.DataFrame(data)

# %%
df5.head()
# Out:
#      a    b    c
# 0  1.0  1.0  1.0
# 1  2.0  NaN  NaN
# 2  NaN  3.0  NaN

# %%
df5.loc[3] = ['4',np.nan,5]

# %%
df5.dropna(axis = 0)
# Out:
#      a    b    c
# 0  1.0  1.0  1.0

# %%
df5.dropna(axis = 1)
# Out:
# Empty DataFrame
# Columns: []
# Index: [0, 1, 2]

# %%
df5.dropna(thresh=2, axis = 1)
# Out:
#      a    b
# 0  1.0  1.0
# 1  2.0  NaN
# 2  NaN  3.0

# %%
df5 = df5.drop(4, axis = 1)

# %%
df5
# Out:
#      a    b    c
# 0  1.0  1.0  1.0
# 1  2.0  NaN  NaN
# 2  NaN  3.0  NaN
# 3    4  NaN  5.0

# %%
df5.fillna(value=3)
# Out:
#      a    b    c    3
# 0  1.0  1.0  1.0  4.0
# 1  2.0  3.0  3.0  3.0
# 2  3.0  3.0  3.0  5.0

# %%
df5
# Out:
#           a         b    c
# 0  1.000000  1.000000  1.0
# 1  2.000000  2.333333  NaN
# 2  2.333333  3.000000  NaN
# 3  4.000000  2.333333  5.0

# %%
df5.fillna(method = 'ffill')
# Out:
#      a    b    c    3
# 0  1.0  1.0  1.0  4.0
# 1  2.0  1.0  1.0  4.0
# 2  2.0  3.0  1.0  5.0

# %%
df5.fillna(method = 'bfill')
# Out:
#      a    b    c
# 0  1.0  1.0  1.0
# 1  2.0  3.0  5.0
# 2    4  3.0  5.0
# 3    4  NaN  5.0

# %%
df5
# Out:
#           a         b    c
# 0       1.0  1.000000  1.0
# 1       2.0  2.333333  NaN
# 2  2.333333  3.000000  NaN
# 3         4       NaN  5.0

# %%
df5['a'] = df5['a'].astype('float64')

# %%
df5['a'] = df5['a'].fillna(value = np.mean(df5['a']))

# %%
df5['b'] = df5['b'].fillna(value = df5['b'].mean())

# %%
df5['c'] = df5['c'].fillna(value = df5['c'].mean())

# %%
df5
# Out:
#           a    b    c
# 0  1.000000  1.0  1.0
# 1  2.000000  2.0  3.0
# 2  2.333333  3.0  3.0
# 3  4.000000  2.0  5.0

# %%
#Normalization
df10 = pd.read_csv('CarPrices.csv')

# %%
df10
# Out:
#      car_ID  symboling                   CarName fueltype aspiration  \
# 0         1          3        alfa-romero giulia      gas        std
# 1         2          3       alfa-romero stelvio      gas        std
# 2         3          1  alfa-romero Quadrifoglio      gas        std
# 3         4          2               audi 100 ls      gas        std
# 4         5          2                audi 100ls      gas        std
# ..      ...        ...                       ...      ...        ...
# 200     201         -1           volvo 145e (sw)      gas        std
# 201     202         -1               volvo 144ea      gas      turbo
# 202     203         -1               volvo 244dl      gas        std
# 203     204         -1                 volvo 246   diesel      turbo
# 204     205         -1               volvo 264gl      gas      turbo
#
#     doornumber      carbody drivewheel enginelocation  wheelbase  ...  \
# ...

# %%
df10.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205 entries, 0 to 204
# Data columns (total 26 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   car_ID            205 non-null    int64
#  1   symboling         205 non-null    int64
#  2   CarName           205 non-null    object
#  3   fueltype          205 non-null    object
#  4   aspiration        205 non-null    object
#  5   doornumber        205 non-null    object
#  6   carbody           205 non-null    object
#  7   drivewheel        205 non-null    object
#  8   enginelocation    205 non-null    object
#  9   wheelbase         205 non-null    float64
#  10  carlength         205 non-null    float64
#  11  carwidth          205 non-null    float64
#  12  carheight         205 non-null    float64
#  13  curbweight        205 non-null    int64
#  14  enginetype        205 non-null    object
#  15  cylindernumber    205 non-null    object
# ...

# %%
df10[['CarBrand','CarName1']] = df10['CarName'].str.split(' ', expand=True)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-200-b298fa1cb807> in <cell line: 1>()
# ----> 1 df10[['CarBrand','CarName1']] = df10['CarName'].str.split(' ', expand=True)
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in __setitem__(self, key, value)
#    3966             self._setitem_frame(key, value)
#    3967         elif isinstance(key, (Series, np.ndarray, list, Index)):
# -> 3968             self._setitem_array(key, value)
#    3969         elif isinstance(value, DataFrame):
#    3970             self._set_item_frame_value(key, value)
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in _setitem_array(self, key, value)
#    4008
#    4009             if isinstance(value, DataFrame):
# -> 4010                 check_key_length(self.columns, key, value)
#    4011                 for k1, k2 in zip(key, value.columns):
# ...

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
#Single field scaling
df10['SF_rpm'] = df10['peakrpm']/df10['peakrpm'].max()

# %%
df10
# Out:
#      car_ID  symboling                   CarName fueltype aspiration  \
# 0         1          3        alfa-romero giulia      gas        std
# 1         2          3       alfa-romero stelvio      gas        std
# 2         3          1  alfa-romero Quadrifoglio      gas        std
# 3         4          2               audi 100 ls      gas        std
# 4         5          2                audi 100ls      gas        std
# ..      ...        ...                       ...      ...        ...
# 200     201         -1           volvo 145e (sw)      gas        std
# 201     202         -1               volvo 144ea      gas      turbo
# 202     203         -1               volvo 244dl      gas        std
# 203     204         -1                 volvo 246   diesel      turbo
# 204     205         -1               volvo 264gl      gas      turbo
#
#     doornumber      carbody drivewheel enginelocation  wheelbase  ...  \
# ...

# %%
#Min-Max scaling
df10['MM_rpm'] = (df10['peakrpm']-df10['peakrpm'].min())/(df10['peakrpm'].max()-df10['peakrpm'].min())

# %%
df10
# Out:
#      car_ID  symboling                   CarName fueltype aspiration  \
# 0         1          3        alfa-romero giulia      gas        std
# 1         2          3       alfa-romero stelvio      gas        std
# 2         3          1  alfa-romero Quadrifoglio      gas        std
# 3         4          2               audi 100 ls      gas        std
# 4         5          2                audi 100ls      gas        std
# ..      ...        ...                       ...      ...        ...
# 200     201         -1           volvo 145e (sw)      gas        std
# 201     202         -1               volvo 144ea      gas      turbo
# 202     203         -1               volvo 244dl      gas        std
# 203     204         -1                 volvo 246   diesel      turbo
# 204     205         -1               volvo 264gl      gas      turbo
#
#     doornumber      carbody drivewheel enginelocation  wheelbase  ...  \
# ...

# %%
# !pip install scipy

# %%
from scipy.stats import zscore

# %%
df11 = pd.read_csv('HousePrices.csv')

# %%
df11.head()
# Out:
#                   date      price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# 0  2014-05-02 00:00:00   313000.0       3.0       1.50         1340      7912
# 1  2014-05-02 00:00:00  2384000.0       5.0       2.50         3650      9050
# 2  2014-05-02 00:00:00   342000.0       3.0       2.00         1930     11947
# 3  2014-05-02 00:00:00   420000.0       3.0       2.25         2000      8030
# 4  2014-05-02 00:00:00   550000.0       4.0       2.50         1940     10500
#
#    floors  waterfront  view  condition  sqft_above  sqft_basement  yr_built  \
# 0     1.5           0     0          3        1340              0      1955
# 1     2.0           0     4          5        3370            280      1921
# 2     1.0           0     0          4        1930              0      1966
# 3     1.0           0     0          4        1000           1000      1963
# 4     1.0           0     0          4        1140            800      1976
#
# ...

# %%
df11['price'].plot()
# Out:
# <Axes: >

# %%
df11['price'].hist()
# Out:
# <Axes: >

# %%
#Outliers
df11[df11['price'] > 10000000]
# Out:
#                      date       price  bedrooms  bathrooms  sqft_living  \
# 4346  2014-06-23 00:00:00  12899000.0       3.0        2.5         2190
# 4350  2014-07-03 00:00:00  26590000.0       3.0        2.0         1180
#
#       sqft_lot  floors  waterfront  view  condition  sqft_above  \
# 4346     11394     1.0           0     0          3        1550
# 4350      7793     1.0           0     0          4        1180
#
#       sqft_basement  yr_built  yr_renovated             street     city  \
# 4346            640      1956          2001    5426 40th Ave W  Seattle
# 4350              0      1992             0  12005 SE 219th Ct     Kent
#
#       statezip country
# 4346  WA 98199     USA
# 4350  WA 98031     USA

# %%
df11['zcore_price'] = zscore(df11['price'])

# %%
df11[df11['price'] > 10000000]
# Out:
#                      date       price  bedrooms  bathrooms  sqft_living  \
# 4346  2014-06-23 00:00:00  12899000.0       3.0        2.5         2190
# 4350  2014-07-03 00:00:00  26590000.0       3.0        2.0         1180
#
#       sqft_lot  floors  waterfront  view  condition  sqft_above  \
# 4346     11394     1.0           0     0          3        1550
# 4350      7793     1.0           0     0          4        1180
#
#       sqft_basement  yr_built  yr_renovated             street     city  \
# 4346            640      1956          2001    5426 40th Ave W  Seattle
# 4350              0      1992             0  12005 SE 219th Ct     Kent
#
#       statezip country  zcore_price
# 4346  WA 98199     USA    21.900708
# 4350  WA 98031     USA    46.185287

# %%
df11[df11['zcore_price']>= 20]
# Out:
#                      date       price  bedrooms  bathrooms  sqft_living  \
# 4346  2014-06-23 00:00:00  12899000.0       3.0        2.5         2190
# 4350  2014-07-03 00:00:00  26590000.0       3.0        2.0         1180
#
#       sqft_lot  floors  waterfront  view  condition  sqft_above  \
# 4346     11394     1.0           0     0          3        1550
# 4350      7793     1.0           0     0          4        1180
#
#       sqft_basement  yr_built  yr_renovated             street     city  \
# 4346            640      1956          2001    5426 40th Ave W  Seattle
# 4350              0      1992             0  12005 SE 219th Ct     Kent
#
#       statezip country  zcore_price
# 4346  WA 98199     USA    21.900708
# 4350  WA 98031     USA    46.185287

# %%
thresh = 20
df11['outliers'] = np.where(abs(df11['zcore_price']) > thresh, 'outlier','non-outlier')

# %%
df11.outliers.value_counts()
# Out:
# non-outlier    4598
# outlier           2
# Name: outliers, dtype: int64

# %%
df11
# Out:
#                      date         price  bedrooms  bathrooms  sqft_living  \
# 0     2014-05-02 00:00:00  3.130000e+05       3.0       1.50         1340
# 1     2014-05-02 00:00:00  2.384000e+06       5.0       2.50         3650
# 2     2014-05-02 00:00:00  3.420000e+05       3.0       2.00         1930
# 3     2014-05-02 00:00:00  4.200000e+05       3.0       2.25         2000
# 4     2014-05-02 00:00:00  5.500000e+05       4.0       2.50         1940
# ...                   ...           ...       ...        ...          ...
# 4595  2014-07-09 00:00:00  3.081667e+05       3.0       1.75         1510
# 4596  2014-07-09 00:00:00  5.343333e+05       3.0       2.50         1460
# 4597  2014-07-09 00:00:00  4.169042e+05       3.0       2.50         3010
# 4598  2014-07-10 00:00:00  2.034000e+05       4.0       2.00         2090
# 4599  2014-07-10 00:00:00  2.206000e+05       3.0       2.50         1490
#
#       sqft_lot  floors  waterfront  view  condition  sqft_above  \
# ...
